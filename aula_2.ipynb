# %%
# basic imports
import pandas as pd

# google imports 
import pandas_gbq 
from google.oauth2 import service_account 
from google.cloud import bigquery

# %%
credentials = service_account.Credentials.from_service_account_file(filename='gbq_keys.json',
                                                                    scopes=['https://www.googleapis.com/auth/cloud-platform'])

pandas_gbq.context.credentials = credentials
pandas_gbq.context.project = "leandro-project"

# %%
# criando um objeto chamado client, que sera usado para chamar os metodos
client = bigquery.Client(credentials=credentials)

# %% [markdown]
# # AULA 2 - IN, BETWEEN, LIKE e NOT

# %% [markdown]
# - ORDER BY sigla_partido => faz os resultados sairem em ordem alfabetica
# - ORDER BY sigla_partido DESC => faz os resultados sairem em ordem alfabetica invertida (Z - A)

# %%
# Query to select countries with units of "ppm"
query =  """
              SELECT DISTINCT(sigla_partido)
              FROM `basedosdados.br_poder360_pesquisas.microdados`
              WHERE ano >= 2014 
              AND sigla_partido != 'N/A' 
              AND sigla_partido != 'sem partido'
              ORDER BY sigla_partido
              """

# Set up the query (cancel the query if it would use too much of 
# your quota, with the limit set to 10 GB)
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)
query_job = client.query(query, job_config=safe_config)

# API request - run the query, and return a pandas DataFrame
results = query_job.to_dataframe()

# View top few rows of results
results
# Out:
#     sigla_partido
# 0            Agir
# 1          Avante
# 2       Cidadania
# 3              DC
# 4             DEM
# 5             FFB
# 6          Livres
# 7             MDB
# 8            Novo
# 9             PAN
# 10        PC do B
# 11            PCB
# 12            PCO
# 13            PDT
# 14            PEN
# 15            PFL
# 16            PHS
# 17             PL
# 18            PMB
# 19           PMDB
# 20            PMN
# 21             PP
# 22            PPL
# 23            PPS
# 24             PR
# 25            PRB
# 26            PRP
# 27           PRTB
# 28            PSB
# 29            PSC
# 30            PSD
# 31           PSDB
# 32           PSDC
# 33            PSL
# 34           PSTU
# 35             PT
# 36        PT do B
# 37            PTB
# 38            PTC
# 39            PTN
# 40             PV
# 41       Patriota
# 42        Podemos
# 43  Progressistas
# 44           Pros
# 45           Psol
# 46           Rede
# 47   Republicanos
# 48             SD
# 49             UP
# 50   União Brasil

# %% [markdown]
# - (AND sigla_partido != 'N/A') = (AND NOT sigla_partido = 'N/A')

# %%
# Query to select countries with units of "ppm"
query =  """
              SELECT DISTINCT(sigla_partido)
              FROM `basedosdados.br_poder360_pesquisas.microdados`
              WHERE ano >= 2014 
              AND NOT sigla_partido = 'N/A' 
              AND NOT sigla_partido = 'sem partido'
              ORDER BY sigla_partido DESC
              """

# Set up the query (cancel the query if it would use too much of 
# your quota, with the limit set to 10 GB)
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**10)
query_job = client.query(query, job_config=safe_config)

# API request - run the query, and return a pandas DataFrame
results = query_job.to_dataframe()

# View top few rows of results
results
# Out:
#     sigla_partido
# 0    União Brasil
# 1              UP
# 2              SD
# 3    Republicanos
# 4            Rede
# 5            Psol
# 6            Pros
# 7   Progressistas
# 8         Podemos
# 9        Patriota
# 10             PV
# 11            PTN
# 12            PTC
# 13            PTB
# 14        PT do B
# 15             PT
# 16           PSTU
# 17            PSL
# 18           PSDC
# 19           PSDB
# 20            PSD
# 21            PSC
# 22            PSB
# 23           PRTB
# 24            PRP
# 25            PRB
# 26             PR
# 27            PPS
# 28            PPL
# 29             PP
# 30            PMN
# 31           PMDB
# 32            PMB
# 33             PL
# 34            PHS
# 35            PFL
# 36            PEN
# 37            PDT
# 38            PCO
# 39            PCB
# 40        PC do B
# 41            PAN
# 42           Novo
# 43            MDB
# 44         Livres
# 45            FFB
# 46            DEM
# 47             DC
# 48      Cidadania
# 49         Avante
# 50           Agir
